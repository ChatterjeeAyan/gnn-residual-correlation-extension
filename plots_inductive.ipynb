# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
##inductive gnn data
ind_gnn_ising_pos=np.asarray([0.671, 0.649, 0.654, 0.662, 0.663, 0.659, 0.664, 0.668, 0.672, 0.663, 0.665, 0.666, 0.676])
ind_gnn_error_ising_pos=np.asarray([0.023, 0.036, 0.031, 0.027, 0.032, 0.031, 0.031, 0.022, 0.022, 0.025, 0.040, 0.024, 0.027])

ind_gnn_ising_neg=np.asarray([0.515, 0.503, 0.494, 0.492, 0.500, 0.497, 0.487, 0.484, 0.492, 0.488, 0.490, 0.484, 0.474])
ind_gnn_error_ising_neg=np.asarray( [     0.006,      0.007,      0.007,      0.011,      0.009,      0.010,      0.010,      0.010,      0.016,      0.015,      0.014,      0.016,      0.018])

ind_gnn_income=np.asarray([0.693, 0.720, 0.728, 0.735, 0.739, 0.741, 0.747, 0.745, 0.751, 0.749, 0.749, 0.747, 0.751])
ind_gnn_error_income=np.asarray([     0.006,      0.007,      0.007,      0.011,      0.009,      0.010,      0.010,      0.010,      0.016,      0.015,      0.014,      0.016,      0.018])

ind_gnn_education=np.asarray([0.703, 0.698, 0.701, 0.717, 0.717, 0.725, 0.726, 0.728, 0.731, 0.734, 0.737, 0.737, 0.731]) 
ind_gnn_error_education=np.asarray([0.008, 0.010, 0.012, 0.009, 0.013, 0.005, 0.011, 0.010, 0.008, 0.011, 0.017, 0.010, 0.015])

ind_gnn_unemployment=np.asarray([0.407, 0.482, 0.497, 0.517, 0.525, 0.529, 0.532, 0.544, 0.537, 0.556, 0.552, 0.557, 0.555])
ind_gnn_error_unemployment=np.asarray([0.049, 0.041, 0.041, 0.046, 0.049, 0.035, 0.040, 0.034, 0.034, 0.046, 0.036, 0.040, 0.041])

ind_gnn_election=np.asarray([0.369, 0.504, 0.529, 0.553, 0.560, 0.572, 0.568, 0.580, 0.583, 0.591, 0.599, 0.597, 0.599]) 
ind_gnn_error_election=np.asarray([0.034, 0.020, 0.026, 0.020, 0.026, 0.016, 0.025, 0.020, 0.015, 0.019, 0.016, 0.023, 0.024])

# %%
##inductive cgnn data
ind_cgnn_ising_pos=np.asarray([0.657, 0.676, 0.692, 0.716, 0.727, 0.736, 0.736, 0.743, 0.747, 0.757, 0.764, 0.768, 0.770]) 
ind_cgnn_error_ising_pos=np.asarray([0.035,0.030,0.033,0.020,0.024,0.025, 0.025,0.022,0.015, 0.018,0.023, 0.017, 0.025])

ind_cgnn_ising_neg=np.asarray([0.512, 0.614, 0.669, 0.686, 0.704, 0.717, 0.728, 0.735, 0.740, 0.766, 0.759, 0.772, 0.775])
ind_cgnn_error_ising_neg=np.asarray([0.008, 0.023, 0.025, 0.023, 0.019, 0.020, 0.015, 0.028, 0.024, 0.016, 0.024, 0.016, 0.016])

ind_cgnn_income=np.asarray([0.685, 0.710, 0.727, 0.745, 0.751, 0.762, 0.760, 0.764, 0.770, 0.781, 0.782, 0.787, 0.778])
ind_cgnn_error_income=np.asarray([0.018, 0.016, 0.021, 0.015, 0.017, 0.017, 0.017, 0.012, 0.015, 0.013, 0.020, 0.012, 0.018])

ind_cgnn_education=np.asarray([0.692, 0.699, 0.706, 0.712, 0.710, 0.712, 0.717, 0.718, 0.724, 0.734, 0.727, 0.732, 0.722])
ind_cgnn_error_education=np.asarray([0.016, 0.013, 0.016, 0.012, 0.020, 0.017, 0.015, 0.015, 0.010, 0.017, 0.018, 0.015, 0.017])

ind_cgnn_unemployment=np.asarray([0.355, 0.564, 0.650, 0.677, 0.692, 0.709, 0.720, 0.722, 0.732, 0.746, 0.748, 0.745, 0.751])
ind_cgnn_error_unemployment=np.asarray([0.040, 0.046, 0.020, 0.020, 0.011, 0.014, 0.017, 0.011, 0.018, 0.006, 0.018, 0.022, 0.013])

ind_cgnn_election=np.asarray([0.387, 0.513, 0.569, 0.600, 0.619, 0.645, 0.655, 0.665, 0.667, 0.682, 0.683, 0.692, 0.693])
ind_cgnn_error_election=np.asarray([0.030, 0.020, 0.017, 0.017, 0.021, 0.013, 0.012, 0.011, 0.016, 0.010, 0.014, 0.014, 0.014])

# %%
##inductive MLP data
ind_mlp_ising_pos=np.asarray([0.686, 0.664, 0.662, 0.664, 0.679, 0.670, 0.677, 0.674, 0.681, 0.675, 0.679, 0.679, 0.682])
ind_mlp_error_ising_pos=np.asarray( [     0.029,0.032,0.027,0.021,0.029,0.040,0.029,0.023,0.029,0.026,0.031,0.033,0.031])

ind_mlp_ising_neg=np.asarray([0.515, 0.501, 0.496, 0.496, 0.497, 0.496, 0.491, 0.489, 0.503, 0.487, 0.495, 0.490, 0.485])
ind_mlp_error_ising_neg=np.asarray([0.006, 0.008, 0.006, 0.011, 0.007, 0.010, 0.012, 0.009, 0.016, 0.017, 0.013, 0.018, 0.025])

ind_mlp_income=np.asarray([0.596, 0.590, 0.600, 0.606, 0.608, 0.613, 0.611, 0.619, 0.621, 0.618, 0.627, 0.618, 0.625])
ind_mlp_error_income=np.asarray([0.012, 0.013, 0.008, 0.012, 0.009, 0.006, 0.010, 0.013, 0.014, 0.018, 0.015, 0.024, 0.015])

ind_mlp_education=np.asarray([0.689, 0.682, 0.689, 0.697, 0.699, 0.706, 0.706, 0.707, 0.712, 0.712, 0.716, 0.711, 0.706])
ind_mlp_error_education=np.asarray([0.007, 0.011, 0.012, 0.007, 0.009, 0.005, 0.009, 0.010, 0.011, 0.013, 0.015, 0.016, 0.012])

ind_mlp_unemployment=np.asarray([0.340, 0.374, 0.400, 0.414, 0.427, 0.432, 0.435, 0.443, 0.443, 0.455, 0.458, 0.463, 0.457])
ind_mlp_error_unemployment=np.asarray([0.033, 0.024, 0.038, 0.036, 0.035, 0.026, 0.038, 0.030, 0.032, 0.033, 0.036, 0.032, 0.036])

ind_mlp_election=np.asarray([0.297, 0.391, 0.411, 0.431, 0.444, 0.447, 0.454, 0.461, 0.464, 0.475, 0.471, 0.465, 0.474])
ind_mlp_error_election=np.asarray([0.015, 0.024, 0.021, 0.020, 0.017, 0.018, 0.022, 0.018, 0.021, 0.016, 0.031, 0.027, 0.031])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-61b46094f8a6> in <module>
#       1 plt.plot(frac, ind_gnn_income,label="GNN",color="orange")
# ----> 2 plt.fill_between(frac, ind_gnn_income-ing_gnn_error_income, ind_gnn_income+ing_gnn_error_income,color="orange",alpha=0.2)
#       3 plt.plot(frac, ind_cgnn_income,label="C-GNN",color="green")
#       4 plt.fill_between(frac, ind_cgnn_income-ing_cgnn_error_income, ind_cgnn_income+ing_cgnn_error_income,color="green",alpha=0.2)
#       5 plt.plot(frac, ind_mlp_income,label="MLP",color="blue" )
#
# NameError: name 'ing_gnn_error_income' is not defined

# %%
fig = plt.figure()
frac=[0.0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6]
#ising pos

plt.figure(figsize=(14, 8))
plt.xlim([0, 0.6])
plt.subplot(3, 2, 1)

plt.ylim([0.2,1])
plt.ylabel('accuracy')


plt.plot(frac, ind_gnn_ising_pos,label="GNN",color="orange")
plt.fill_between(frac, ind_gnn_ising_pos-ind_gnn_error_ising_pos, ind_gnn_ising_pos+ind_gnn_error_ising_pos,color="orange",alpha=0.2)
plt.plot(frac, ind_cgnn_ising_pos,label="C-GNN",color="green")
plt.fill_between(frac, ind_cgnn_ising_pos-ind_cgnn_error_ising_pos, ind_cgnn_ising_pos+ind_cgnn_error_ising_pos,color="green",alpha=0.2)
plt.plot(frac, ind_mlp_ising_pos,label="MLP",color="blue" )
plt.fill_between(frac, ind_mlp_ising_pos-ind_mlp_error_ising_pos, ind_mlp_ising_pos+ind_mlp_error_ising_pos,color="blue",alpha=0.2)
plt.grid()
plt.title("Ising (+)",y=0.80)


#ising neg



plt.subplot(3, 2, 2)
plt.plot(frac, ind_gnn_ising_neg,label="GNN",color="orange")
plt.fill_between(frac, ind_gnn_ising_neg-ind_gnn_error_ising_neg, ind_gnn_ising_neg+ind_gnn_error_ising_neg,color="orange",alpha=0.2)
plt.plot(frac, ind_cgnn_ising_neg,label="C-GNN",color="green")
plt.fill_between(frac, ind_cgnn_ising_neg-ind_cgnn_error_ising_neg, ind_cgnn_ising_neg+ind_cgnn_error_ising_neg,color="green",alpha=0.2)
plt.plot(frac, ind_mlp_ising_neg,label="MLP",color="blue" )
plt.fill_between(frac, ind_mlp_ising_neg-ind_mlp_error_ising_neg, ind_mlp_ising_neg+ind_mlp_error_ising_neg,color="blue",alpha=0.2)
plt.title("Ising (-)",y=0.80)

plt.ylim([0.2,1])
plt.grid()

#income
plt.subplot(3, 2, 3)
plt.plot(frac, ind_gnn_income,label="GNN",color="orange")
plt.fill_between(frac, ind_gnn_income-ind_gnn_error_income, ind_gnn_income+ind_gnn_error_income,color="orange",alpha=0.2)
plt.plot(frac, ind_cgnn_income,label="C-GNN",color="green")
plt.fill_between(frac, ind_cgnn_income-ind_cgnn_error_income, ind_cgnn_income+ind_cgnn_error_income,color="green",alpha=0.2)
plt.plot(frac, ind_mlp_income,label="MLP",color="blue" )
plt.fill_between(frac, ind_mlp_income-ind_mlp_error_income, ind_mlp_income+ind_mlp_error_income,color="blue",alpha=0.2)
plt.ylabel('R²')
plt.title("income",y=0.80)

plt.ylim([0.2,1])
plt.grid()

#education
plt.subplot(3, 2, 4)
plt.plot(frac, ind_gnn_education,label="GNN",color="orange")
plt.fill_between(frac, ind_gnn_education-ind_gnn_error_education, ind_gnn_education+ind_gnn_error_education,color="orange",alpha=0.2)
plt.plot(frac, ind_cgnn_education,label="C-GNN",color="green")
plt.fill_between(frac, ind_cgnn_education-ind_cgnn_error_education, ind_cgnn_education+ind_cgnn_error_education,color="green",alpha=0.2)
plt.plot(frac, ind_mlp_education,label="MLP",color="blue" )
plt.fill_between(frac, ind_mlp_education-ind_mlp_error_education, ind_mlp_education+ind_mlp_error_education,color="blue",alpha=0.2)
plt.title("education",y=0.80)

plt.ylim([0.2,1])
plt.grid()

#employment
plt.subplot(3, 2, 5)
plt.plot(frac, ind_gnn_unemployment,label="GNN",color="orange")
plt.fill_between(frac, ind_gnn_unemployment-ind_gnn_error_unemployment, ind_gnn_unemployment+ind_gnn_error_unemployment,color="orange",alpha=0.2)
plt.plot(frac, ind_cgnn_unemployment,label="C-GNN",color="green")
plt.fill_between(frac, ind_cgnn_unemployment-ind_cgnn_error_unemployment, ind_cgnn_unemployment+ind_cgnn_error_unemployment,color="green",alpha=0.2)
plt.plot(frac, ind_mlp_unemployment,label="MLP",color="blue" )
plt.fill_between(frac, ind_mlp_unemployment-ind_mlp_error_unemployment, ind_mlp_unemployment+ind_mlp_error_unemployment,color="blue",alpha=0.2)
plt.ylabel('R²')
plt.xlabel('Fraction of labeled verrtices L\'')
plt.title("unemployment",y=0.80)
plt.ylim([0.2,1])
plt.grid()

#election
plt.subplot(3, 2, 6)
plt.plot(frac, ind_gnn_election,label="GNN",color="orange")
plt.fill_between(frac, ind_gnn_election-ind_gnn_error_election, ind_gnn_election+ind_gnn_error_election,color="orange",alpha=0.2)
plt.plot(frac, ind_cgnn_election,label="C-GNN",color="green")
plt.fill_between(frac, ind_cgnn_election-ind_cgnn_error_election, ind_cgnn_election+ind_cgnn_error_election,color="green",alpha=0.2)
plt.plot(frac, ind_mlp_election,label="MLP",color="blue" )
plt.fill_between(frac, ind_mlp_election-ind_mlp_error_election, ind_mlp_election+ind_mlp_error_election,color="blue",alpha=0.2)
plt.ylim([0.2,1])
plt.xlabel('Fraction of labeled verrtices L\'')
plt.grid()
plt.title("election",y=0.80)
plt.legend()

plt.show()
